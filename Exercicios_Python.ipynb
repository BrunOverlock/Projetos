# %% [markdown]
# <a href="https://colab.research.google.com/github/BrunOverlock/Projetos/blob/main/Exercicios_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
numero = int(input("Informe um numero inteiro: "))
quadrado = numero**2
print(f'O quadrado do numero informado é: {quadrado}')

#Para fazer soma do quadrado
# Out:
# Informe um numero inteiro: 5
# O quadrado do numero informado é: 25

# %% [markdown]
# IMPORT MATH.POW

# %%
import math

numero1 = int(input("Informe o numero inteiro: "))
quadrado= int(math.pow(numero1,2))
print(f'O quadrado do numero informado é: {quadrado}')
# Out:
# Informe o numero inteiro: 5
# O quadrado do numero informado é: 25

# %%
print(pow(9,1/2))
# Out:
# 3.0

# %% [markdown]
# MOSTRAR O QUE O USUARIO DIGITAR

# %%
carac1= input("Digite o primeiro numero: ")
carac2= input("Dgite o segundo numero: ")
print(f'O usuario digitou {carac1} e {carac2}')
# Out:
# Digite o primeiro numero: 23
# Dgite o segundo numero: 45
# O usuario digitou 23 e 45

# %% [markdown]
# Exercicio 3

# %%
numero = int(input("Informe o numero inteiro: "))
antes= numero-1
depois = numero+1
print(f"O numero anterior é: {antes}")
print(f"O numero sucessor é: {depois}")
# Out:
# Informe o numero inteiro: 10
# O numero anterior é: 9
# O numero sucessor é: 11

# %% [markdown]
# Exercico 4

# %%
base =  float(input("Informe a base do retangulo: "))
altura = float(input("Informe a altura do retangulo: "))

perimetro = 2* (base + altura)
area =  base * altura
print(f"O perimetro do retangulo é: {perimetro}")
print(f"A area do retangulo é: {area}")
# Out:
# Informe a base do retangulo: 5.6
# Informe a altura do retangulo: 5
# O perimetro do retangulo é: 21.2
# A area do retangulo é: 28.0

# %% [markdown]
# Exercicio 5
# Taxa de juros simples

# %%
valor = float(input("Informe o valor da prestação: "))
taxa = float(input("Informe a taza do juros, sem sinais: "))
tempo = float(input("Informe o tempo de atraso em meses: "))
